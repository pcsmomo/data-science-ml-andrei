# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
# Import training and validation sets (sorted)
df_tmp = pd.read_csv("../data/bluebook-for-bulldozers/TrainAndValid-sorted.csv",
                 low_memory=False,
                 parse_dates=["saledate"])
